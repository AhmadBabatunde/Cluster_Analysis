# %% [markdown]
# # How to Choose the Number of Clusters

# %% [markdown]
# Using the same code as in the previous exercise, find the WCSS for clustering solutions with 1 to 10 clusters (you can try with more if you wish).
#
# Find the most suitable solutions, run them and compare the results.

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Countries_exercise.csv'</i>.

# %%
data = pd.read_csv('Countries_exercise.csv')
data.head()
# Out:
#           name  Longitude   Latitude
# 0        Aruba -69.982677  12.520880
# 1  Afghanistan  66.004734  33.835231
# 2       Angola  17.537368 -12.293361
# 3     Anguilla -63.064989  18.223959
# 4      Albania  20.049834  41.142450

# %% [markdown]
# Remove the duplicate index column from the dataset.

# %%
data.drop_duplicates()
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %% [markdown]
# ## Plot the data

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %%
plt.scatter(data['Longitude'],data['Latitude'])
plt.show()

# %% [markdown]
# ## Select the features

# %% [markdown]
# Make sure to select the appropriate features since we are no longer using the categorical variable for our clustering but rather <i>'Longitude'</i> and <i>'Laditude'</i>.

# %%
x = data.iloc[:,-2:]
x
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %% [markdown]
# ## Clustering

# %% [markdown]
# Use 4 clusters initially.

# %%
kmeans = KMeans(4)
kmeans.fit(x)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4)

# %% [markdown]
# ### Clustering results

# %%
result = kmeans.fit_predict(x)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
data_w = data.copy()
data_w['cluster_result'] = result
data_w.head()
# Out:
#           name  Longitude   Latitude  cluster_result
# 0        Aruba -69.982677  12.520880               0
# 1  Afghanistan  66.004734  33.835231               1
# 2       Angola  17.537368 -12.293361               1
# 3     Anguilla -63.064989  18.223959               0
# 4      Albania  20.049834  41.142450               2

# %% [markdown]
# Plot the data once again but separate the data by the clusters we defined.

# %% [markdown]
# ## Plot the data

# %%
plt.scatter(data_w['Longitude'],data_w['Latitude'],c=data_w['cluster_result'],cmap='rainbow')
plt.show()

# %% [markdown]
# ## Selecting the number of clusters

# %% [markdown]
# ### WCSS

# %% [markdown]
# Use the ingerated <i>sklearn</i> method <i> 'inertia_' </i>.

# %%
kmeans.inertia_
# Out:
# 256590.585754061

# %% [markdown]
# Write a loop that calculates and saves the WCSS for any number of clusters from 1 up to 10 (or more if you wish).

# %%
wcss = []
num = range(1,17)
for i in num:
    kmeans = KMeans(i)
    kmeans.fit(x)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
wcss
# Out:
# [1413859.6798344273,
#  657012.0797586325,
#  325235.52237055893,
#  256595.22356029777,
#  192194.98290025245,
#  151883.98694078985,
#  127560.17498392079,
#  102873.25264457408,
#  84945.19461239543,
#  76615.77904339501,
#  69396.2275917706,
#  64382.66620283628,
#  58820.93944673778,
#  55814.49984556934,
#  51040.006700959304,
#  47273.57868859338]

# %% [markdown]
# ### The Elbow Method

# %%
number_clusters = num
plt.plot(number_clusters, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')

# %% [markdown]
# Based on the Elbow Curve, plot several graphs with the appropriate amounts of clusters you believe would best fit the data.

# %% [markdown]
# Compare the scatter plots to determine which one to use in our further analysis.

# %% [markdown]
# 3 number of cluster seems to be the optimum number of cluster from the line plot above

# %% [markdown]
# <i>Hint: we already created the scatter plot for 4 clusters, so we only have to slightly alter our code.</i>

# %%
kmeans2 = KMeans(3)
kmeans2.fit(x)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
result2 = kmeans2.fit_predict(x)
data_w2 = data.copy()
data_w2['Cluter Result'] = result2
data_w2.head()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#           name  Longitude   Latitude  Cluter Result
# 0        Aruba -69.982677  12.520880              1
# 1  Afghanistan  66.004734  33.835231              0
# 2       Angola  17.537368 -12.293361              0
# 3     Anguilla -63.064989  18.223959              1
# 4      Albania  20.049834  41.142450              0

# %%
plt.scatter(data_w2['Longitude'],data_w2['Latitude'],c=data_w2['Cluter Result'],cmap='rainbow')
plt.show()

# %%
kmeans3 = KMeans(2)
kmeans3.fit(x)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
result3 = kmeans3.fit_predict(x)
data_w3 =data.copy()
data_w3['result_cluster'] = result3
data_w3.head()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#           name  Longitude   Latitude  result_cluster
# 0        Aruba -69.982677  12.520880               1
# 1  Afghanistan  66.004734  33.835231               0
# 2       Angola  17.537368 -12.293361               0
# 3     Anguilla -63.064989  18.223959               1
# 4      Albania  20.049834  41.142450               0

# %%
plt.scatter(data_w3['Longitude'],data_w3['Latitude'],c=data_w3['result_cluster'],cmap='rainbow')
plt.show()
